# %%
import pandas as pd
df=pd.read_excel(r"C:\Users\yvsur\Downloads\temperature.xlsx")
df
# Out:
#          date       city  temperature  humidity condition
# 0  2025-04-12  hyderabad           23        32     sunny
# 1  2025-04-13  hyderabad           43        55     sunny
# 2  2025-04-14  hyderabad           32        33     sunny
# 3  2025-04-15   banglore           54        97    cloudy
# 4  2025-04-16   banglore           12        47    cloudy
# 5  2025-04-17   banglore           65        49    cloudy
# 6  2025-04-18    chennai           56        61    cloudy
# 7  2025-04-19        kkd           45        82    cloudy
# 8  2025-04-20      vizag           87        83     sunny
# 9  2025-04-21      vizag           66        23    cloudy
# 10 2025-04-22  vijaywada           33        11     sunny
# 11 2025-04-23  vijaywada           22        76    cloudy

# %%
df.head()
# Out:
#         date       city  temperature  humidity condition
# 0 2025-04-12  hyderabad           23        32     sunny
# 1 2025-04-13  hyderabad           43        55     sunny
# 2 2025-04-14  hyderabad           32        33     sunny
# 3 2025-04-15   banglore           54        97    cloudy
# 4 2025-04-16   banglore           12        47    cloudy

# %%
df.tail()
# Out:
#          date       city  temperature  humidity condition
# 7  2025-04-19        kkd           45        82    cloudy
# 8  2025-04-20      vizag           87        83     sunny
# 9  2025-04-21      vizag           66        23    cloudy
# 10 2025-04-22  vijaywada           33        11     sunny
# 11 2025-04-23  vijaywada           22        76    cloudy

# %%
df.head(2)
# Out:
#         date       city  temperature  humidity condition
# 0 2025-04-12  hyderabad           23        32     sunny
# 1 2025-04-13  hyderabad           43        55     sunny

# %%
df.tail(7)
# Out:
#          date       city  temperature  humidity condition
# 5  2025-04-17   banglore           65        49    cloudy
# 6  2025-04-18    chennai           56        61    cloudy
# 7  2025-04-19        kkd           45        82    cloudy
# 8  2025-04-20      vizag           87        83     sunny
# 9  2025-04-21      vizag           66        23    cloudy
# 10 2025-04-22  vijaywada           33        11     sunny
# 11 2025-04-23  vijaywada           22        76    cloudy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         12 non-null     datetime64[ns]
#  1   city         12 non-null     object
#  2   temperature  12 non-null     int64
#  3   humidity     12 non-null     int64
#  4   condition    12 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 612.0+ bytes

# %%
df.shape
# Out:
# (12, 5)

# %%
df[2:5]
# Out:
#         date       city  temperature  humidity condition
# 2 2025-04-14  hyderabad           32        33     sunny
# 3 2025-04-15   banglore           54        97    cloudy
# 4 2025-04-16   banglore           12        47    cloudy

# %%
df.columns
# Out:
# Index(['date', 'city', 'temperature', 'humidity', 'condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df.dtypes
# Out:
# date           datetime64[ns]
# city                   object
# temperature             int64
# humidity                int64
# condition              object
# dtype: object

# %%
df.date
# Out:
# 0    2025-04-12
# 1    2025-04-13
# 2    2025-04-14
# 3    2025-04-15
# 4    2025-04-16
# 5    2025-04-17
# 6    2025-04-18
# 7    2025-04-19
# 8    2025-04-20
# 9    2025-04-21
# 10   2025-04-22
# 11   2025-04-23
# Name: date, dtype: datetime64[ns]

# %%
df["date"]
# Out:
# 0    2025-04-12
# 1    2025-04-13
# 2    2025-04-14
# 3    2025-04-15
# 4    2025-04-16
# 5    2025-04-17
# 6    2025-04-18
# 7    2025-04-19
# 8    2025-04-20
# 9    2025-04-21
# 10   2025-04-22
# 11   2025-04-23
# Name: date, dtype: datetime64[ns]

# %%
df[["date","condition"]]
# Out:
#          date condition
# 0  2025-04-12     sunny
# 1  2025-04-13     sunny
# 2  2025-04-14     sunny
# 3  2025-04-15    cloudy
# 4  2025-04-16    cloudy
# 5  2025-04-17    cloudy
# 6  2025-04-18    cloudy
# 7  2025-04-19    cloudy
# 8  2025-04-20     sunny
# 9  2025-04-21    cloudy
# 10 2025-04-22     sunny
# 11 2025-04-23    cloudy

# %%
df["date"][df["condition"]=="sunny"]
# Out:
# 0    2025-04-12
# 1    2025-04-13
# 2    2025-04-14
# 8    2025-04-20
# 10   2025-04-22
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ### reading data

# %%
import pandas as pd
df=pd.DataFrame({
    "name":["kaveri","niha","sweety","prash","ramya","yamuna","devi"],
    "rollno":[3,9,54,41,52,37,56]
})
df
# Out:
#      name  rollno
# 0  kaveri       3
# 1    niha       9
# 2  sweety      54
# 3   prash      41
# 4   ramya      52
# 5  yamuna      37
# 6    devi      56

# %%
df.head()
# Out:
#      name  rollno
# 0  kaveri       3
# 1    niha       9
# 2  sweety      54
# 3   prash      41
# 4   ramya      52

# %%
df.tail()
# Out:
#      name  rollno
# 2  sweety      54
# 3   prash      41
# 4   ramya      52
# 5  yamuna      37
# 6    devi      56

# %%
df.head(3)
# Out:
#      name  rollno
# 0  kaveri       3
# 1    niha       9
# 2  sweety      54

# %%
df.tail(1)
# Out:
#    name  rollno
# 6  devi      56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   rollno  7 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 244.0+ bytes

# %%
df.shape
# Out:
# (7, 2)

# %%
df.name
# Out:
# 0    kaveri
# 1      niha
# 2    sweety
# 3     prash
# 4     ramya
# 5    yamuna
# 6      devi
# Name: name, dtype: object

# %%
df.rollno
# Out:
# 0     3
# 1     9
# 2    54
# 3    41
# 4    52
# 5    37
# 6    56
# Name: rollno, dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'rollno'], dtype='object')

# %%
df[1:5]
# Out:
#      name  rollno
# 1    niha       9
# 2  sweety      54
# 3   prash      41
# 4   ramya      52

# %%
df[["name","rollno"]]
# Out:
#      name  rollno
# 0  kaveri       3
# 1    niha       9
# 2  sweety      54
# 3   prash      41
# 4   ramya      52
# 5  yamuna      37
# 6    devi      56

# %%
df['name']
# Out:
# 0    kaveri
# 1      niha
# 2    sweety
# 3     prash
# 4     ramya
# 5    yamuna
# 6      devi
# Name: name, dtype: object

# %%
df['name'][df["rollno"]==3]
# Out:
# 0    kaveri
# Name: name, dtype: object
